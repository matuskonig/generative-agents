# %%
import pandas as pd

# %% [markdown]
# # Dictatorship game source data

# %%
original_data_df = pd.read_csv("dictator_game_original_paper_data.csv")
original_data_df.head()
# Out:
#    Month      Game Pay/No Pay  Value  Rejected
# 0  April  Dictator        Pay    0.0     False
# 1  April  Dictator        Pay    1.0     False
# 2  April  Dictator        Pay    1.0     False
# 3  April  Dictator        Pay    2.5     False
# 4  April  Dictator        Pay    0.0     False

# %%
original_data_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 182 entries, 0 to 181
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Month       182 non-null    str
#  1   Game        182 non-null    str
#  2   Pay/No Pay  182 non-null    str
#  3   Value       182 non-null    float64
#  4   Rejected    182 non-null    bool
# dtypes: bool(1), float64(1), str(3)
# memory usage: 6.0 KB
